# %% [markdown]
# # 인공지능응용 2주차 실습
#
# **AI 주제를 설명하는 나의 Notebook**
#
# 1. Google Drive에 사본을 저장하세요.
# 2. 파일명을 **이름_학번_2주차.ipynb**로 바꾸세요.
# 3. 위에서부터 진행하며 `작성할 내용`을 자신의 말로 채우세요.
#
# 이 문서는 이번 단원의 개편된 실습 교재입니다. 이 Notebook의 본인 사본에서 실습을 진행합니다. 예시·힌트·빈칸을 그대로 제출하지 않습니다. 문서 구조를 자유롭게 바꾸되 현재 과제 요구사항을 만족해야 합니다.
#
# **실습 환경:** Python 기본 런타임. GPU·개인 Drive 마운트·추가 설치가 필요하지 않습니다.
#
# [현재 과제 안내](https://niilab.notion.site/Week-2-Assignment-25f888a17b30802db04df421f243d46d?pvs=25)
#
# 자료 버전: 2026-2-02 / 현재 과제 마감: 2026-09-10 23:59 (변경 시 KLAS 안내 우선)

# %% [markdown]
# ## 0. 실행 확인 — 코드 실행과 결과 설명
#
# 아래는 연습용 코드입니다. 실행 버튼이나 Shift+Enter를 누르세요. 평균이 22.0으로 출력되는지 확인합니다. 리스트의 값 하나를 바꾸면 평균은 어떻게 달라질까요?

# %%
readings = [20, 22, 24]
average = sum(readings) / len(readings)
print("평균:", average)

# %% [markdown]
# 이 Code Cell은 계산을 실행합니다. 지금 읽는 Markdown Cell은 설명을 표시합니다. 다른 종류의 셀에 같은 내용을 넣었을 때 무엇이 달라지는지 떠올려보세요.
#
# 아래부터가 자신의 AI 주제 보고서 작성란입니다. 텍스트 셀은 두 번 클릭해 편집할 수 있습니다.

# %% [markdown]
# # 작성할 내용: 내가 선택한 AI 주제
#
# 이름: 작성할 내용
# 학번: 작성할 내용
#
# ## 1. 기술 소개
#
# ### 어떤 문제를 해결하는가?
#
# 작성할 내용: 선택한 기술을 **3–5문장**으로 소개하세요. 기술이 무엇인지, 어떤 데이터를 사용하는지, 무엇을 해결하는지, 어디에 활용되는지를 포함합니다.
#
# 힌트: 한 문장으로 이름을 정의하는 데서 끝내지 말고, 처음 보는 사람이 입력과 결과를 떠올릴 수 있게 쓰세요.
#
# ## 2. 핵심 용어와 특징
#
# 작성할 내용: **굵게**, *기울임*, `인라인 코드`를 각각 1회 이상 자신의 내용에 적용하세요. 위 예시 문법을 남기는 것만으로 대신하지 않습니다.
#
# 순서 없는 목록(최소 3항목):
# - 작성할 내용
# - 작성할 내용
# - 작성할 내용
#
# ## 3. AI 처리 과정
#
# 순서 있는 목록으로 본인의 주제에 맞게 4단계 이상 작성하세요. 이렇게 작성하면 순서 목록의 최소 3항목 조건도 만족합니다.
#
# 1. 작성할 내용
# 2. 작성할 내용
# 3. 작성할 내용
# 4. 작성할 내용

# %% [markdown]
# ## 4. 관련 이미지
#
# 작성할 내용: 관련 이미지를 1개 이상 **실제로 표시**하고 아래에 1–2문장으로 설명하세요.
#
# 문법 힌트(이 코드 블록 자체는 이미지가 아닙니다):
# ```markdown
# ![이미지가 보여주는 내용](실제_이미지_주소)
# ```
#
# 이미지 설명: 작성할 내용 — 무엇을 나타내며 선택한 AI 주제와 어떻게 관련되는가?
#
# 이미지만 있고 설명이 없으면 미완성입니다. 개인에게만 접근 가능한 이미지 링크라면 다른 사람이 열 수 있는지도 확인하세요.

# %% [markdown]
# ## 5. 비교 표
#
# 작성할 내용: 3개 이상의 열, 4개 이상의 **데이터 행**을 채우세요. 제목 행은 데이터 행이 아닙니다. 열 제목도 본인의 비교 기준으로 바꾸세요.
#
# | 비교 대상 | 입력/특징 | 결과/활용 |
# |---|---|---|
# | 작성할 내용 | 작성할 내용 | 작성할 내용 |
# | 작성할 내용 | 작성할 내용 | 작성할 내용 |
# | 작성할 내용 | 작성할 내용 | 작성할 내용 |
# | 작성할 내용 | 작성할 내용 | 작성할 내용 |
#
# 힌트: AI 분야끼리 비교하거나, 선택한 기술의 활용 사례 등을 비교할 수 있습니다. 표의 모든 행에서 열의 의미가 일관되어야 합니다.

# %% [markdown]
# ## 6. 수식과 의미
#
# 작성할 내용: LaTeX 수식 **2개 이상**, 각 수식의 의미 **1문장 이상**을 적으세요. 가능하면 선택한 AI 주제나 데이터 분석과 관련된 식을 고르세요.
#
# 수식 문법을 기억하려면 자습 자료의 평균 예제를 참고하세요. 복잡한 식보다 자신이 기호의 의미를 설명할 수 있는 식이 좋습니다.
#
# ### 수식 1
#
# 작성할 내용: 이 위치에 실제로 렌더링되는 수식을 넣으세요.
#
# 설명: 작성할 내용
#
# ### 수식 2
#
# 작성할 내용: 이 위치에 실제로 렌더링되는 수식을 넣으세요.
#
# 설명: 작성할 내용
#
# 수식만 있고 의미 설명이 없으면 미완성입니다.

# %% [markdown]
# ## 7. 참고자료 링크
#
# 작성할 내용: 본인의 AI 주제와 관련된 자료를 1개 이상 골라 Markdown 링크로 넣으세요.
#
# 문법 힌트:
# ```markdown
# [자료 이름](실제_자료_주소)
# ```
#
# 선택 이유 또는 확인할 수 있는 내용(1–2문장): 작성할 내용

# %% [markdown]
# ## 8. 지정 Code Cell 실행
#
# 아래는 현재 과제에 지정된 코드입니다. 실행하고 결과를 확인하세요. 출력에 표시된 수와 리스트의 항목 수가 일치하는지 확인합니다.

# %%
ai_fields = [
    "Computer Vision",
    "Natural Language Processing",
    "Robotics",
    "Generative AI"
]
print("Number of AI fields:", len(ai_fields))

# %% [markdown]
# ### Markdown Cell과 Code Cell의 차이
#
# Q1. 위 코드는 왜 Markdown Cell이 아니라 Code Cell에서 실행해야 하나요?
#
# 작성할 내용:
#
# Q2. 두 셀의 차이를 2가지 이상 적으세요.
#
# 1. 작성할 내용
# 2. 작성할 내용

# %% [markdown]
# ## 9. Markdown 오류 수정
#
# 아래 셀은 **일부러 잘못 작성된 문제**입니다. 셀을 편집하여 제목·굵게·순서 목록·표가 정상적으로 표시되도록 고치세요. 단순히 답을 붙여 넣기보다 어느 기호가 어떤 역할을 하는지 확인합니다.
#
# 막히면 자습 자료의 제목 공백, 강조 기호의 짝, 번호 목록의 형식, 표의 헤더 구분선을 확인하세요.

# %% [markdown]
# #Artificial Intelligence
#
# ##Computer Vision
#
# **Object Detection*
#
# 1 Computer Vision
# 2 Natural Language Processing
# 3 Robotics
#
# |Model|Accuracy
# |YOLO|0.92
# |CNN|0.87

# %% [markdown]
# ## 10. 제출 전 확인
#
# - [ ] 파일명은 이름_학번_2주차.ipynb이다.
# - [ ] 주제 소개 3–5문장과 AI 처리 과정 4단계 이상을 작성했다.
# - [ ] 제목 3단계, 굵게·기울임·인라인 코드, 두 종류 목록을 확인했다.
# - [ ] 이미지 1개 이상과 설명 1–2문장이 있다.
# - [ ] 표는 3열 이상이며 데이터 행은 4개 이상이다.
# - [ ] 수식 2개 이상을 넣고 각각의 의미를 설명했다.
# - [ ] 관련 링크와 선택 이유/내용 설명이 있다.
# - [ ] 지정 코드를 실행하고 셀의 차이를 2가지 이상 설명했다.
# - [ ] Markdown 오류 수정 문제를 고쳤다.
# - [ ] 모든 셀을 위에서부터 확인했고, 빈칸·힌트·불필요한 예시를 정리했다.
# - [ ] 수정한 내용이 Drive에 저장된 것을 확인했다.
#
# 현재 학기 과제 안내가 변경되면 최신 KLAS·조교 안내를 따릅니다. 제출본에서 스스로 설명할 수 없는 문장이나 수식이 남아 있지 않은지 마지막으로 읽어보세요.
